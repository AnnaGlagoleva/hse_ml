# %% [markdown]
# Задача 1. (макс. 7 баллов)
#
# Скачайте датасет в .xlsx (Excel) "Археологические находки на реконструируемых улицах" с московского портала открытых данных : https://data.mos.ru/opendata/7702155262-arheologicheskie-nahodki-na-rekonstruiruemyh-ulitsah?pageNumber=2&versionNumber=2&releaseNumber=8
#
# (2 балла) Загрузите датасет функцией pandas.read_excel(). Сколько было находок?
# (1 балла) Добавьте в датафрейм колонки с годом и месяцем обнаружения (метод apply)
# (1 балл) Выведете распределение количества находок по годам и отдельно по месяцам (метод value_counts())
# (2 балла) Найдите находку с самым длинным описанием
# (1 балл) Бонусный балл за интересные факты, которые можно почерпнуть из датасета с использованием pandas.

# %%
import pandas as pd
df = pd.read_excel('data-54581-2018-08-28.xlsx')
len(df)
# Out:
# 1226

# %%
df['MonthOfDiscovery'] = df['DateOfDiscovery'].apply(lambda x: x.split('.')[1])
df['YearOfDiscovery'] = df['DateOfDiscovery'].apply(lambda x: x.split('.')[2])

# %%
df['YearOfDiscovery'].value_counts()
# Out:
# 2017    509
# 2015    276
# 2013    260
# 2016    129
# 2018     52
# Name: YearOfDiscovery, dtype: int64

# %%
df['MonthOfDiscovery'].value_counts()
# Out:
# 05    217
# 07    211
# 09    165
# 08    150
# 06    132
# 04    109
# 10     81
# 03     80
# 02     46
# 11     28
# 12      5
# 01      2
# Name: MonthOfDiscovery, dtype: int64

# %%
df['DescriptionOfFinding'].iloc[df['DescriptionOfFinding'].str.len().idxmax()]
# Out:
# 'В южной части Зарядья, помимо большого количества разнообразных деревянных сооружений, в заполнении подклета избы постройки рубежа XVI – XVII вв. был обнаружен уникальный клад серебряных монет в трех сосудах. \nКлад содержал в себе серебряные денги и копейки в количестве до 43 тыс.экземпляров. Фляга.'

# %%
df['DescriptionOfFindingLength'] = df['DescriptionOfFinding'].apply(len)
max_len = df['DescriptionOfFindingLength'].max()
df[df['DescriptionOfFindingLength'] == max_len]['DescriptionOfFinding'].values[0]
# Out:
# 'В южной части Зарядья, помимо большого количества разнообразных деревянных сооружений, в заполнении подклета избы постройки рубежа XVI – XVII вв. был обнаружен уникальный клад серебряных монет в трех сосудах. \nКлад содержал в себе серебряные денги и копейки в количестве до 43 тыс.экземпляров. Фляга.'

# %% [markdown]
# Задача 2. (макс. 10 баллов)
# Вам дан датасет с данными о спортивных площадках в Москве и Московской области с портала открытых данных города москвы. https://data.mos.ru/opendata/7708040885-sportivnye-ploshchadki
#
# (2 балла) Загрузите датасет функцией pandas.read_excel(). Сколько всего площадок?
# (1 балл) Pandas сокращает количество выводимых столбцов, если их слишком много. Выполните pd.set_option('display.max_columns', None) , чтобы выводить всегда все колонки.
# (1 балл) Сколько площадок останется, если удалить строчки, у которых хотя бы 1 значение пропущено (функция pandas.dropna())? Почему столько?
# (2 балла) Выведите все бесплатные площадки, приспособленные для инвалидов
# (1 балл) Какие типы покрытия бывают на площадках (метод unique() у колонки)? Какое покрытие самое популярное, самое непопулярное (метод value_counts())?
# (1 балл) Сколько всего районов, в которых расположены площадки (метод .nunique() у колонки). Какой район имеет наибольшее количество площадок?
# (2 балла) Сколько площадок в вашем районе? На каком месте находится ваш район по кол-ву площадок? (функция np.where() или метод .index())

# %%
import pandas as pd
df = pd.read_excel('data-24776-2019-01-16.xlsx')

# %%
df.head()
# Out:
#    global_id                                         ObjectName  \
# 0  284508021  Некоммерческое партнерство творческий центр «Ш...
# 1  407175195                    Досуговый центр «Центр Вешняки»
# 2  407175351                             Досуговый центр «Русь»
# 3  407175599                      Досуговый центр «Новогиреево»
# 4  407176194  Физкультурно-оздоровительный комплекс «Центр В...
#
#           NameWinter                           PhotoWinter  \
# 0     зал спортивный  3a5b5282-d843-497c-b80a-daffb0de624a
# 1  зал спортивный №3  3cce895d-9d31-4204-be5a-d0444af999ae
# 2  зал спортивный №1  4f8d64b2-7335-489b-9703-e5a5c533cad2
# 3     зал спортивный  3e841db1-92b9-4e3d-a72e-70cb875d380b
# 4  зал спортивный №1  e59d084a-924e-43a9-9976-2bf583c0596d
#
#                             AdmArea                 District  \
# 0   Северный административный округ  район Западное Дегунино
# 1  Восточный административный округ            район Вешняки
# ...

# %%
len(df)
# Out:
# 1508

# %%
pd.set_option('display.max_columns', None)

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [global_id, ObjectName, NameWinter, PhotoWinter, AdmArea, District, Address, Email, WebSite, HelpPhone, HelpPhoneExtension, WorkingHoursWinter, ClarificationOfWorkingHoursWinter, HasEquipmentRental, EquipmentRentalComments, HasTechService, TechServiceComments, HasDressingRoom, HasEatery, HasToilet, HasWifi, HasCashMachine, HasFirstAidPost, HasMusic, UsagePeriodWinter, DimensionsWinter, Lighting, SurfaceTypeWinter, Seats, Paid, PaidComments, DisabilityFriendly, ServicesWinter, geoData]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 34 columns):
# global_id                            1508 non-null int64
# ObjectName                           1508 non-null object
# NameWinter                           1508 non-null object
# PhotoWinter                          1508 non-null object
# AdmArea                              1508 non-null object
# District                             1508 non-null object
# Address                              1508 non-null object
# Email                                1207 non-null object
# WebSite                              1505 non-null object
# HelpPhone                            1502 non-null object
# HelpPhoneExtension                   0 non-null float64
# WorkingHoursWinter                   1508 non-null object
# ClarificationOfWorkingHoursWinter    0 non-null float64
# HasEquipmentRental                   1508 non-null object
# ...

# %%
df[(df['Paid'] == 'бесплатно') & 
    df['DisabilityFriendly'].isin([
       'частично приспособлен',
       'приспособлен для всех групп инвалидов',
       'приспособлен для лиц с нарушением ОДА',])]
# Out:
#       global_id                                         ObjectName  \
# 2     407175351                             Досуговый центр «Русь»
# 16    407198188                         Досуговый центр «Талисман»
# 17    407199296  Государственное бюджетное учреждение Спортивно...
# 18    407199624                          Досуговый центр «Фаворит»
# 41    407232425                 Спортивный зал «на Петрозаводской»
# 42    407232861                  Досуговый центр в районе Аэропорт
# 47    407236583  Физкультурно-оздоровительный комплекс «Тимиряз...
# 48    407236805  Физкультурно-оздоровительный комплекс «Тимиряз...
# 54    407238365  Физкультурно-оздоровительный комплекс «Спортив...
# 55    407238599  Физкультурно-оздоровительный комплекс «Спортив...
# 85    407266188                 Пункт выдачи спортивного инвентаря
# 86    407266672                             Досуговый центр «Русь»
# 115   408332374  Спортивный зал «Спортивная школа № 57 Крылья С...
# ...

# %%
df['SurfaceTypeWinter'].unique()
# Out:
# array(['специальное покрытие', 'деревянное покрытие', 'рулонное покрытие',
#        'заливное покрытие', 'газонное покрытие (искусственное)',
#        'асфальтовое, бетонное покрытие', 'отсыпное покрытие'],
#       dtype=object)

# %%
df['SurfaceTypeWinter'].value_counts()
# Out:
# специальное покрытие                 1060
# деревянное покрытие                   368
# рулонное покрытие                      62
# заливное покрытие                       9
# асфальтовое, бетонное покрытие          5
# отсыпное покрытие                       3
# газонное покрытие (искусственное)       1
# Name: SurfaceTypeWinter, dtype: int64

# %%
df['District'].nunique()
# Out:
# 135

# %%
df['District'].value_counts()
# Out:
# Алексеевский район                 46
# Хорошёвский район                  41
# район Ховрино                      34
# район Измайлово                    33
# район Беговой                      29
# район Сокол                        29
# Войковский район                   28
# район Митино                       27
# район Бибирево                     26
# район Вешняки                      25
# район Отрадное                     25
# район Чертаново Северное           25
# район Черёмушки                    25
# Можайский район                    24
# район Аэропорт                     23
# Тимирязевский район                22
# Ломоносовский район                21
# Головинский район                  21
# Таганский район                    20
# район Коптево                      20
# район Нагатино-Садовники           20
# Савёловский район                  20
# район Текстильщики                 19
# район Савёлки                      19
# Гагаринский район                  19
# ...

# %%
df['District'].value_counts()['район Левобережный']
# Out:
# 7
